# %% [markdown]
# # k-nearest neighbors
# Copyright 2020 Denis Rothman MIT License. See LICENSE.

# %% [markdown]
# ## Program modules

# %%
import pandas as pd
from matplotlib import pyplot as plt
from sklearn.neighbors import KNeighborsClassifier

# %%
df = pd.read_csv('D1.csv')
print(df.head())
# Out:
#    colored_sputum  cough  fever  headache class
# 0             1.0    3.5    9.4       3.0   flu
# 1             1.0    3.4    8.4       4.0   flu
# 2             1.0    3.3    7.3       3.0   flu
# 3             1.0    3.4    9.5       4.0   flu
# 4             1.0    2.0    8.0       3.5   flu

# %% [markdown]
# ## Opening and reading the file

# %% [markdown]
# ## Training the model

# %%
# KNN classification labels
X = df.loc[:,'colored_sputum':'headache']
Y = df.loc[:,'class']

# Trains the model
knn = KNeighborsClassifier()
knn.fit(X,Y)
# Out:
# KNeighborsClassifier()

# %% [markdown]
# ## Display the trained model's output

# %%
# Plotting the relation of each feature with each class
figure,(sub1,sub2,sub3,sub4)=plt.subplots(4,sharex=True,sharey=True)
plt.suptitle('k-nearest neighbors')
plt.xlabel('Feature')
plt.ylabel('Class') 
X = df.loc[:,'colored_sputum']
Y = df.loc[:,'class']
sub1.scatter(X, Y,color='blue',label='colored_sputum')
sub1.legend(loc=4, prop={'size': 5})
sub1.set_title('Medical Diagnosis Software')
X = df.loc[:,'cough']
Y = df.loc[:,'class']
sub2.scatter(X, Y,color='green',label='cough')
sub2.legend(loc=4, prop={'size': 5})
X = df.loc[:,'fever']
Y = df.loc[:,'class']
sub3.scatter(X, Y,color='red',label='fever')
sub3.legend(loc=4, prop={'size': 5})
X = df.loc[:,'headache']
Y = df.loc[:,'class']
sub4.scatter(X, Y,color='black',label='headache')
sub4.legend(loc=4, prop={'size': 5})
figure.subplots_adjust(hspace=0)
plt.show()

# %% [markdown]
# ## Evaluating the symptoms on a scale of 1 to 9

# %%
import ipywidgets as widgets
from IPython.display import display

# Create interactive sliders for each parameter
colored_sputum = widgets.IntSlider(value=1, min=0, max=10, description='Sputum:')
cough = widgets.IntSlider(value=3, min=0, max=10, description='Cough:')
fever = widgets.IntSlider(value=7, min=0, max=10, description='Fever:')
headache = widgets.IntSlider(value=5, min=0, max=10, description='Headache:')

# Display sliders
display(colored_sputum, cough, fever, headache)

# Access the values
def get_values():
    return {
        "Colored Sputum": colored_sputum.value,
        "Cough": cough.value,
        "Fever": fever.value,
        "Headache": headache.value
}

# Example: Print values when needed
print("Set values using the sliders above.")
# Out:
# IntSlider(value=1, description='Sputum:', max=10)
# IntSlider(value=3, description='Cough:', max=10)
# IntSlider(value=7, description='Fever:', max=10)
# IntSlider(value=5, description='Headache:', max=10)
# Set values using the sliders above.

# %% [markdown]
# ## The prediction based on the symptoms

# %%
# colored_sputum,cough,fever,headache
cs=colored_sputum.value;c=cough.value;f=fever.value;h=headache.value;
X_DL = [[cs,c,f,h]] 
prediction = knn.predict(X_DL)
print ("The prediction is:",str(prediction).strip('[]'))
# Out:
# The prediction is: 'flu'
# c:\users\msii\desktop\my_codes\hands-on-explainable-ai-xai-with-python\myenv2\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(
